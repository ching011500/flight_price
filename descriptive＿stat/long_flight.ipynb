# %% [markdown]
# ## 資料檢查

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 繁體中文設定
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
plt.rcParams['axes.unicode_minus'] = False

# 讀取數據
file_path = '/Users/yuchingchen/Documents/專題/merge_and_cleaned/final_data/long_flight.csv'
data = pd.read_csv(file_path)

# 檢查是否有缺失值(僅顯示有缺失值的欄位)
print(data.isnull().sum())
# Out:
# 出發日期                 0
# 出發時間                 0
# 出發時段                 0
# 星期                   0
# 出發機場代號               0
# 抵達時間                 0
# 抵達時段                 0
# 抵達機場代號               0
# 航空公司                 0
# 航空公司（主航段）            0
# 航空聯盟組合               0
# 航空公司組合               0
# 航空聯盟                 0
# 停靠站數量                0
# 停留時間                 0
# 停留時間_分鐘              0
# 飛行時間                 0
# 飛行時間_分鐘              0
# 實際飛行時間_分鐘            0
# 是否過夜                 0
# 機型                   0
# 機型（主航段）              0
# 機型分類                 0
# 航班代碼                 0
# 航班代碼（主航段）            0
# 艙等                   0
# 艙等（主航段）              0
# 第一段飛行時間              3
# 假期                   0
# 第二段飛行時間              3
# 飛行時間兩段分類             0
# 平均價格                 0
# 最低價格                 0
# 中位數價格                0
# 價格變異                 0
# 隨機購買平均價格             0
# 最低價格剩餘天數             0
# 筆數                   0
# 平均價格_log             0
# 最低價格_log             0
# 價格變異_log             0
# 中位數價格_log            0
# 最低價格剩餘天數_log         0
# Region               0
# 經濟指標                 0
# 機場指標                 0
# 是否為平日                0
# competing_flights    0
# 航空公司聯盟分類             0
# dtype: int64

# %% [markdown]
# ## 查看價格的基本統計摘要

# %%
import pandas as pd

# 讀取數據
file_path = '/Users/yuchingchen/Documents/專題/merge_and_cleaned/final_data/long_flight.csv'
data = pd.read_csv(file_path)

# 分離經濟艙與商務艙的數據
economy_class_data = data[data["艙等（主航段）"] == "經濟艙"].copy()
business_class_data = data[data["艙等（主航段）"] == "商務艙"].copy()

# 檢查經濟艙與商務艙的數據分佈
y_cols = ['平均價格', '最低價格', '中位數價格']
print(economy_class_data[y_cols].describe())
print(business_class_data[y_cols].describe())
# Out:
#                 平均價格           最低價格          中位數價格
# count   50204.000000   50204.000000   50204.000000
# mean    38561.477850   33115.996474   37884.716457
# std     30383.907149   29138.185842   30968.882131
# min      6368.000000    5599.000000    6602.000000
# 25%     22236.750000   19433.000000   21523.000000
# 50%     28399.000000   24096.000000   27373.750000
# 75%     39766.500000   30769.500000   38695.500000
# max    237308.000000  228030.000000  243467.000000
#                 平均價格           最低價格          中位數價格
# count   42278.000000   42278.000000   42278.000000
# mean   124242.720800  109224.696722  122433.673660
# std     54545.979707   49010.131726   57059.381832
# min     42767.000000   24481.000000   30596.000000
# 25%     91000.000000   83667.000000   90254.000000
# 50%    107924.000000   97776.000000  104776.500000
# 75%    135279.500000  114355.750000  130772.875000
# max    462710.000000  373580.000000  512438.000000

# %% [markdown]
# ## 查看連續變數的基本統計摘要

# %%
import pandas as pd

# 讀取數據
file_path = '/Users/yuchingchen/Documents/專題/merge_and_cleaned/final_data/long_flight.csv'
data = pd.read_csv(file_path)

# 分離經濟艙與商務艙的數據
economy_class_data = data[data["艙等（主航段）"] == "經濟艙"].copy()
business_class_data = data[data["艙等（主航段）"] == "商務艙"].copy()

# 需要計算描述統計的數值欄位
num_cols = ['停留時間_分鐘', '實際飛行時間_分鐘', '經濟指標', '機場指標', 'competing_flights']

# 顯示這些欄位的描述統計信息
print(economy_class_data[num_cols].describe())
print(business_class_data[num_cols].describe())
# Out:
#             停留時間_分鐘     實際飛行時間_分鐘          經濟指標          機場指標  \
# count  50204.000000  50204.000000  50204.000000  50204.000000
# mean     571.845749    928.561927     -0.088070      0.147472
# std      378.938041    148.536213      1.201621      1.348547
# min        0.000000    560.000000     -1.262158     -2.499110
# 25%      240.000000    810.000000     -0.977473     -1.566180
# 50%      525.000000    960.000000     -0.389354      0.589166
# 75%      820.000000   1020.000000      0.546813      1.050426
# max     2120.000000   2895.000000      2.784272      1.701121
#
#        competing_flights
# count       50204.000000
# mean           68.244622
# std            30.439005
# min             1.000000
# 25%            42.000000
# 50%            71.000000
# 75%            95.000000
# max           126.000000
#             停留時間_分鐘    實際飛行時間_分鐘          經濟指標          機場指標  \
# count  42278.000000  42278.00000  42278.000000  42278.000000
# mean     593.715502    925.28367     -0.041382      0.192251
# std      388.544736    151.53981      1.175289      1.349577
# min        0.000000    560.00000     -1.262158     -2.499110
# 25%      245.000000    795.00000     -0.977473      0.127615
# 50%      580.000000    955.00000     -0.389354      0.589166
# 75%      850.000000   1020.00000      0.546813      1.050426
# max     2120.000000   1615.00000      2.784272      1.701121
#
#        competing_flights
# count       42278.000000
# mean           67.418918
# std            30.399032
# min             1.000000
# 25%            40.000000
# 50%            70.000000
# 75%            94.000000
# max           126.000000

# %% [markdown]
# ## Histogram

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 繁體中文設定
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
plt.rcParams['axes.unicode_minus'] = False

# 讀取數據
file_path = '/Users/yuchingchen/Documents/專題/merge_and_cleaned/final_data/long_flight.csv'
data = pd.read_csv(file_path)

# 分離經濟艙與商務艙的數據
economy_class_data = data[data["艙等（主航段）"] == "經濟艙"].copy()
business_class_data = data[data["艙等（主航段）"] == "商務艙"].copy()

# 要繪製的欄位與標題設定
plot_columns = [
    ("平均價格", "平均價格的分佈", "#FF9999"),
    ("平均價格_log", "平均價格（對數）的分佈", "#FF9999"),
    ("最低價格", "最低價格的分佈", "#99CCFF"),
    ("最低價格_log", "最低價格（對數）的分佈", "#99CCFF"),
    ("中位數價格", "中位數的分佈", "#B3FFCC"),
    ("中位數價格_log", "中位數（對數）的分佈", "#B3FFCC"),
]

def plot_histograms(class_data, class_name):
    fig, axes = plt.subplots(3, 2, figsize=(12, 10))
    bins = 40

    for i, (col, title, color) in enumerate(plot_columns):
        row = i // 2
        col_idx = i % 2
        sns.histplot(class_data[col], bins=bins, color=color, ax=axes[row, col_idx])
        axes[row, col_idx].set_title(f'{class_name} - {title}')
        axes[row, col_idx].set_xlabel(col)
        axes[row, col_idx].set_ylabel('頻率')

    plt.tight_layout()
    plt.show()

# 繪製經濟艙圖表
plot_histograms(economy_class_data, "經濟艙")

# 繪製商務艙圖表
plot_histograms(business_class_data, "商務艙")

# %% [markdown]
# ## 長條圖-各機場數量

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 繁體中文設定
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
plt.rcParams['axes.unicode_minus'] = False

# 讀取資料
file_path = '/Users/yuchingchen/Documents/專題/merge_and_cleaned/final_data/long_flight.csv'
data = pd.read_csv(file_path)

# 分艙等
economy_data = data[data['艙等（主航段）'] == '經濟艙']
business_data = data[data['艙等（主航段）'] == '商務艙']

# 統計每個抵達機場代號的數量
arrival_counts = data['抵達機場代號'].value_counts()

# 繪製柱狀圖
plt.figure(figsize=(10, 6))
ax = sns.barplot(x=arrival_counts.index, y=arrival_counts.values, color='skyblue')

# 在每個柱子上顯示數字
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=12, color='black', xytext=(0, 10), textcoords='offset points')

# 設定圖表標題和軸標籤
plt.title('各抵達機場代號數量分佈')
plt.xlabel('抵達機場代號')
plt.ylabel('數量')

# 顯示圖表
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 長條圖-個變數中數量

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 繁體中文設定
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
plt.rcParams['axes.unicode_minus'] = False

# 讀取數據
file_path = '/Users/yuchingchen/Documents/專題/merge_and_cleaned/final_data/long_flight.csv'
data = pd.read_csv(file_path)

# ===== 資料前處理 =====
departure_order = ["凌晨班機", "早晨班機", "上午班機", "下午班機", "晚間班機"]
data['出發時段'] = pd.Categorical(data['出發時段'], categories=departure_order, ordered=True)

arrival_order = ["凌晨抵達", "早晨抵達", "上午抵達", "下午抵達", "晚間抵達"]
data['抵達時段'] = pd.Categorical(data['抵達時段'], categories=arrival_order, ordered=True)

alliance_mapping = {
    1: '星空聯盟', 2: '天合聯盟', 3: '寰宇一家', 4: '價值聯盟',
    5: '無聯盟傳統航空', 6: '無聯盟廉價航空'
}
data['航空聯盟'] = data['航空聯盟'].replace(alliance_mapping)
alliance_order = list(alliance_mapping.values())
data['航空聯盟'] = pd.Categorical(data['航空聯盟'], categories=alliance_order, ordered=True)

category_mapping = {0: '窄體機', 1: '寬體機', 2: '超大型客機'}
data['機型分類'] = data['機型分類'].map(category_mapping)
category_order = list(category_mapping.values())
data['機型分類'] = pd.Categorical(data['機型分類'], categories=category_order, ordered=True)

weekday_order = ["星期一", "星期二", "星期三", "星期四", "星期五", "星期六", "星期日"]
data['星期'] = pd.Categorical(data['星期'], categories=weekday_order, ordered=True)

# ===== 分艙等 =====
economy_data = data[data['艙等（主航段）'] == '經濟艙']
business_data = data[data['艙等（主航段）'] == '商務艙']

# ===== 要畫的分類變數（長程）=====
categorical_cols = [
    '出發時段', '抵達時段', '航空聯盟', '機型分類', '假期', '出發機場代號',
    '是否為平日', '飛行時間兩段分類', '航空公司組合', '航空聯盟組合'
]

# ===== 畫子圖函式（含數量標籤）=====
def plot_counts_grid(df, class_name):
    fig, axes = plt.subplots(5, 2, figsize=(20, 25))
    axes = axes.flatten()

    for idx, col in enumerate(categorical_cols):
        counts = df[col].value_counts().sort_index()
        sns.barplot(x=counts.index, y=counts.values, hue=counts.index,
                    palette='pastel', dodge=False, legend=False, ax=axes[idx])

        # 加上每個長條的數量標籤
        for container in axes[idx].containers:
            axes[idx].bar_label(container, fmt='%d', label_type='edge', fontsize=10, padding=2)

        axes[idx].set_title(f"{class_name} - {col}", fontsize=14)
        axes[idx].set_xlabel(col, fontsize=12)
        axes[idx].set_ylabel('數量', fontsize=12)
        axes[idx].tick_params(axis='x', rotation=30)
        axes[idx].grid(axis='y', linestyle='--', linewidth=0.5)

    # 如果子圖格子太多，可以選擇隱藏沒用到的
    if len(categorical_cols) < len(axes):
        for j in range(len(categorical_cols), len(axes)):
            axes[j].axis('off')

    plt.suptitle(f"{class_name} 分類變數數量分布", fontsize=22, y=1.02)
    plt.tight_layout()
    plt.show()

# ===== 執行：各艙等畫一張圖 =====
plot_counts_grid(economy_data, "經濟艙")
plot_counts_grid(business_data, "商務艙")

# %% [markdown]
# ## Boxplot:平均價格_log

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 繁體中文設定
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
plt.rcParams['axes.unicode_minus'] = False

# 讀取數據
file_path = '/Users/yuchingchen/Documents/專題/merge_and_cleaned/final_data/long_flight.csv'
data = pd.read_csv(file_path)

# ===== 資料前處理 =====
# 出發時段排序
departure_order = ["凌晨班機", "早晨班機", "上午班機", "下午班機", "晚間班機"]
data['出發時段'] = pd.Categorical(data['出發時段'], categories=departure_order, ordered=True)

# 抵達時段排序
arrival_order = ["凌晨抵達", "早晨抵達", "上午抵達", "下午抵達", "晚間抵達"]
data['抵達時段'] = pd.Categorical(data['抵達時段'], categories=arrival_order, ordered=True)

# 航空聯盟分類
alliance_mapping = {
    1: '星空聯盟',
    2: '天合聯盟',
    3: '寰宇一家',
    4: '價值聯盟',
    5: '無聯盟傳統航空',
    6: '無聯盟廉價航空'
}
data['航空聯盟'] = data['航空聯盟'].replace(alliance_mapping)
alliance_order = list(alliance_mapping.values())
data['航空聯盟'] = pd.Categorical(data['航空聯盟'], categories=alliance_order, ordered=True)

# 機型分類
category_mapping = {0: '窄體機', 1: '寬體機', 2: '超大型客機'}
data['機型分類'] = data['機型分類'].map(category_mapping)
category_order = list(category_mapping.values())
data['機型分類'] = pd.Categorical(data['機型分類'], categories=category_order, ordered=True)

# 星期排序
weekday_order = ["星期一", "星期二", "星期三", "星期四", "星期五", "星期六", "星期日"]
data['星期'] = pd.Categorical(data['星期'], categories=weekday_order, ordered=True)

# 分艙等
economy_data = data[data['艙等（主航段）'] == '經濟艙']
business_data = data[data['艙等（主航段）'] == '商務艙']

# ===== 設定變數 =====
y_col_var = '平均價格_log'
y_label_text = '平均價格（對數）'
title_fontsize = 18
label_fontsize = 14

# ===== 繪圖函式 =====
def plot_box(data, x_col, y_col, ax, title, x_label, y_label, color):
    sns.boxplot(data=data, x=x_col, y=y_col, ax=ax, color=color)
    ax.set_title(title, fontsize=title_fontsize)
    ax.set_xlabel(x_label, fontsize=label_fontsize)
    ax.set_ylabel(y_label, fontsize=label_fontsize)
    ax.grid(axis='y', linestyle='--', linewidth=0.5)

def draw_boxplots_for_class(class_data, class_name):
    fig, axes = plt.subplots(5, 2, figsize=(20, 24))

    plot_box(class_data.sort_values('出發時段'), '出發時段', y_col_var, axes[0, 0],
             f'{class_name} - 出發時間', '出發時間', y_label_text, '#FF9999')
    plot_box(class_data.sort_values('抵達時段'), '抵達時段', y_col_var, axes[0, 1],
             f'{class_name} - 抵達時間', '抵達時間', y_label_text, '#FFF2CC')
    plot_box(class_data.sort_values('航空聯盟'), '航空聯盟', y_col_var, axes[1, 0],
             f'{class_name} - 航空聯盟', '航空聯盟', y_label_text, '#99CCFF')
    plot_box(class_data.sort_values('機型分類'), '機型分類', y_col_var, axes[1, 1],
             f'{class_name} - 機型分類', '機型分類', y_label_text, '#B3FFCC')
    plot_box(class_data, '假期', y_col_var, axes[2, 0],
             f'{class_name} - 假期', '假期', y_label_text, '#FFCC99')
    plot_box(class_data, '出發機場代號', y_col_var, axes[2, 1],
             f'{class_name} - 出發機場代號', '出發機場代號', y_label_text, '#CCCCFF')
    plot_box(class_data, '是否為平日', y_col_var, axes[3, 0],
             f'{class_name} - 是否為平日', '是否為平日', y_label_text, '#FF9999')
    plot_box(class_data, '飛行時間兩段分類', y_col_var, axes[3, 1],
             f'{class_name} - 飛行時間兩段分類', '飛行時間兩段分類', y_label_text, '#99CCFF')
    plot_box(class_data, '航空公司組合', y_col_var, axes[4, 0],
             f'{class_name} - 航空公司組合', '航空公司組合', y_label_text, '#FFF2CC')
    plot_box(class_data, '航空聯盟組合', y_col_var, axes[4, 1],
             f'{class_name} - 航空聯盟組合', '航空聯盟組合', y_label_text, '#B3FFCC')
    
    plt.tight_layout()
    plt.show()

# 繪製經濟艙 & 商務艙
draw_boxplots_for_class(economy_data, "經濟艙")
draw_boxplots_for_class(business_data, "商務艙")

# %% [markdown]
# ## boxplot:中位數價格_log

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 繁體中文設定
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
plt.rcParams['axes.unicode_minus'] = False

# 讀取數據
file_path = '/Users/yuchingchen/Documents/專題/merge_and_cleaned/final_data/long_flight.csv'
data = pd.read_csv(file_path)

# ===== 資料前處理 =====
# 出發時段排序
departure_order = ["凌晨班機", "早晨班機", "上午班機", "下午班機", "晚間班機"]
data['出發時段'] = pd.Categorical(data['出發時段'], categories=departure_order, ordered=True)

# 抵達時段排序
arrival_order = ["凌晨抵達", "早晨抵達", "上午抵達", "下午抵達", "晚間抵達"]
data['抵達時段'] = pd.Categorical(data['抵達時段'], categories=arrival_order, ordered=True)

# 航空聯盟分類
alliance_mapping = {
    1: '星空聯盟',
    2: '天合聯盟',
    3: '寰宇一家',
    4: '價值聯盟',
    5: '無聯盟傳統航空',
    6: '無聯盟廉價航空'
}
data['航空聯盟'] = data['航空聯盟'].replace(alliance_mapping)
alliance_order = list(alliance_mapping.values())
data['航空聯盟'] = pd.Categorical(data['航空聯盟'], categories=alliance_order, ordered=True)

# 機型分類
category_mapping = {0: '窄體機', 1: '寬體機', 2: '超大型客機'}
data['機型分類'] = data['機型分類'].map(category_mapping)
category_order = list(category_mapping.values())
data['機型分類'] = pd.Categorical(data['機型分類'], categories=category_order, ordered=True)

# 星期排序
weekday_order = ["星期一", "星期二", "星期三", "星期四", "星期五", "星期六", "星期日"]
data['星期'] = pd.Categorical(data['星期'], categories=weekday_order, ordered=True)

# 分艙等
economy_data = data[data['艙等（主航段）'] == '經濟艙']
business_data = data[data['艙等（主航段）'] == '商務艙']

# ===== 設定變數 =====
y_col_var = '中位數價格_log'
y_label_text = '中位數價格（對數）'
title_fontsize = 18
label_fontsize = 14

# ===== 繪圖函式 =====
def plot_box(data, x_col, y_col, ax, title, x_label, y_label, color):
    sns.boxplot(data=data, x=x_col, y=y_col, ax=ax, color=color)
    ax.set_title(title, fontsize=title_fontsize)
    ax.set_xlabel(x_label, fontsize=label_fontsize)
    ax.set_ylabel(y_label, fontsize=label_fontsize)
    ax.grid(axis='y', linestyle='--', linewidth=0.5)

def draw_boxplots_for_class(class_data, class_name):
    fig, axes = plt.subplots(5, 2, figsize=(20, 24))

    plot_box(class_data.sort_values('出發時段'), '出發時段', y_col_var, axes[0, 0],
             f'{class_name} - 出發時間', '出發時間', y_label_text, '#FF9999')
    plot_box(class_data.sort_values('抵達時段'), '抵達時段', y_col_var, axes[0, 1],
             f'{class_name} - 抵達時間', '抵達時間', y_label_text, '#FFF2CC')
    plot_box(class_data.sort_values('航空聯盟'), '航空聯盟', y_col_var, axes[1, 0],
             f'{class_name} - 航空聯盟', '航空聯盟', y_label_text, '#99CCFF')
    plot_box(class_data.sort_values('機型分類'), '機型分類', y_col_var, axes[1, 1],
             f'{class_name} - 機型分類', '機型分類', y_label_text, '#B3FFCC')
    plot_box(class_data, '假期', y_col_var, axes[2, 0],
             f'{class_name} - 假期', '假期', y_label_text, '#FFCC99')
    plot_box(class_data, '出發機場代號', y_col_var, axes[2, 1],
             f'{class_name} - 出發機場代號', '出發機場代號', y_label_text, '#CCCCFF')
    plot_box(class_data, '是否為平日', y_col_var, axes[3, 0],
             f'{class_name} - 是否為平日', '是否為平日', y_label_text, '#FF9999')
    plot_box(class_data, '飛行時間兩段分類', y_col_var, axes[3, 1],
             f'{class_name} - 飛行時間兩段分類', '飛行時間兩段分類', y_label_text, '#99CCFF')
    plot_box(class_data, '航空公司組合', y_col_var, axes[4, 0],
             f'{class_name} - 航空公司組合', '航空公司組合', y_label_text, '#FFF2CC')
    plot_box(class_data, '航空聯盟組合', y_col_var, axes[4, 1],
             f'{class_name} - 航空聯盟組合', '航空聯盟組合', y_label_text, '#B3FFCC')
    
    plt.tight_layout()
    plt.show()

# 繪製經濟艙 & 商務艙
draw_boxplots_for_class(economy_data, "經濟艙")
draw_boxplots_for_class(business_data, "商務艙")

# %% [markdown]
# ## boxplot:最低價格_log

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 繁體中文設定
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
plt.rcParams['axes.unicode_minus'] = False

# 讀取數據
file_path = '/Users/yuchingchen/Documents/專題/merge_and_cleaned/final_data/long_flight.csv'
data = pd.read_csv(file_path)

# ===== 資料前處理 =====
# 出發時段排序
departure_order = ["凌晨班機", "早晨班機", "上午班機", "下午班機", "晚間班機"]
data['出發時段'] = pd.Categorical(data['出發時段'], categories=departure_order, ordered=True)

# 抵達時段排序
arrival_order = ["凌晨抵達", "早晨抵達", "上午抵達", "下午抵達", "晚間抵達"]
data['抵達時段'] = pd.Categorical(data['抵達時段'], categories=arrival_order, ordered=True)

# 航空聯盟分類
alliance_mapping = {
    1: '星空聯盟',
    2: '天合聯盟',
    3: '寰宇一家',
    4: '價值聯盟',
    5: '無聯盟傳統航空',
    6: '無聯盟廉價航空'
}
data['航空聯盟'] = data['航空聯盟'].replace(alliance_mapping)
alliance_order = list(alliance_mapping.values())
data['航空聯盟'] = pd.Categorical(data['航空聯盟'], categories=alliance_order, ordered=True)

# 機型分類
category_mapping = {0: '窄體機', 1: '寬體機', 2: '超大型客機'}
data['機型分類'] = data['機型分類'].map(category_mapping)
category_order = list(category_mapping.values())
data['機型分類'] = pd.Categorical(data['機型分類'], categories=category_order, ordered=True)

# 星期排序
weekday_order = ["星期一", "星期二", "星期三", "星期四", "星期五", "星期六", "星期日"]
data['星期'] = pd.Categorical(data['星期'], categories=weekday_order, ordered=True)

# 分艙等
economy_data = data[data['艙等（主航段）'] == '經濟艙']
business_data = data[data['艙等（主航段）'] == '商務艙']

# ===== 設定變數 =====
y_col_var = '最低價格_log'
y_label_text = '最低價格（對數）'
title_fontsize = 18
label_fontsize = 14

# ===== 繪圖函式 =====
def plot_box(data, x_col, y_col, ax, title, x_label, y_label, color):
    sns.boxplot(data=data, x=x_col, y=y_col, ax=ax, color=color)
    ax.set_title(title, fontsize=title_fontsize)
    ax.set_xlabel(x_label, fontsize=label_fontsize)
    ax.set_ylabel(y_label, fontsize=label_fontsize)
    ax.grid(axis='y', linestyle='--', linewidth=0.5)

def draw_boxplots_for_class(class_data, class_name):
    fig, axes = plt.subplots(5, 2, figsize=(20, 24))

    plot_box(class_data.sort_values('出發時段'), '出發時段', y_col_var, axes[0, 0],
             f'{class_name} - 出發時間', '出發時間', y_label_text, '#FF9999')
    plot_box(class_data.sort_values('抵達時段'), '抵達時段', y_col_var, axes[0, 1],
             f'{class_name} - 抵達時間', '抵達時間', y_label_text, '#FFF2CC')
    plot_box(class_data.sort_values('航空聯盟'), '航空聯盟', y_col_var, axes[1, 0],
             f'{class_name} - 航空聯盟', '航空聯盟', y_label_text, '#99CCFF')
    plot_box(class_data.sort_values('機型分類'), '機型分類', y_col_var, axes[1, 1],
             f'{class_name} - 機型分類', '機型分類', y_label_text, '#B3FFCC')
    plot_box(class_data, '假期', y_col_var, axes[2, 0],
             f'{class_name} - 假期', '假期', y_label_text, '#FFCC99')
    plot_box(class_data, '出發機場代號', y_col_var, axes[2, 1],
             f'{class_name} - 出發機場代號', '出發機場代號', y_label_text, '#CCCCFF')
    plot_box(class_data, '是否為平日', y_col_var, axes[3, 0],
             f'{class_name} - 是否為平日', '是否為平日', y_label_text, '#FF9999')
    plot_box(class_data, '飛行時間兩段分類', y_col_var, axes[3, 1],
             f'{class_name} - 飛行時間兩段分類', '飛行時間兩段分類', y_label_text, '#99CCFF')
    plot_box(class_data, '航空公司組合', y_col_var, axes[4, 0],
             f'{class_name} - 航空公司組合', '航空公司組合', y_label_text, '#FFF2CC')
    plot_box(class_data, '航空聯盟組合', y_col_var, axes[4, 1],
             f'{class_name} - 航空聯盟組合', '航空聯盟組合', y_label_text, '#B3FFCC')
    
    plt.tight_layout()
    plt.show()

# 繪製經濟艙 & 商務艙
draw_boxplots_for_class(economy_data, "經濟艙")
draw_boxplots_for_class(business_data, "商務艙")

# %% [markdown]
# ## 平均價格_log vs. 出發日期

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 字體與樣式
plt.rcParams['font.family'] = 'Arial Unicode MS'
plt.rcParams['axes.unicode_minus'] = False

# 讀資料
file_path = '/Users/yuchingchen/Documents/專題/merge_and_cleaned/final_data/long_flight.csv'
data = pd.read_csv(file_path)

# 日期格式處理
data['出發日期'] = pd.to_datetime(data['出發日期'])

# 分艙等
economy_data = data[data['艙等（主航段）'] == '經濟艙']
business_data = data[data['艙等（主航段）'] == '商務艙']

# 設定畫布與子圖
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(14, 10), sharex=True)

# --- 經濟艙 ---
sns.boxplot(x='出發日期', y='平均價格_log', data=economy_data, ax=axes[0], color='skyblue')
axes[0].axhline(economy_data['平均價格_log'].mean(), color='blue', linestyle='--', linewidth=1.5)
axes[0].set_title('經濟艙 - 平均價格（log）分布', fontsize=14, weight='bold')
axes[0].set_ylabel('平均價格（log）', fontsize=12)
axes[0].tick_params(axis='x', rotation=45)

# --- 商務艙 ---
sns.boxplot(x='出發日期', y='平均價格_log', data=business_data, ax=axes[1], color='navajowhite')
axes[1].axhline(business_data['平均價格_log'].mean(), color='darkorange', linestyle='--', linewidth=1.5)
axes[1].set_title('商務艙 - 平均價格（log）分布', fontsize=14, weight='bold')
axes[1].set_xlabel('出發日期', fontsize=12)
axes[1].set_ylabel('平均價格（log）', fontsize=12)
axes[1].tick_params(axis='x', rotation=45)

# 整體美化
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 最低價格_log vs. 出發日期

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 字體與樣式
plt.rcParams['font.family'] = 'Arial Unicode MS'
plt.rcParams['axes.unicode_minus'] = False

# 讀資料
file_path = '/Users/yuchingchen/Documents/專題/merge_and_cleaned/final_data/long_flight.csv'
data = pd.read_csv(file_path)

# 日期格式處理
data['出發日期'] = pd.to_datetime(data['出發日期'])

# 分艙等
economy_data = data[data['艙等（主航段）'] == '經濟艙']
business_data = data[data['艙等（主航段）'] == '商務艙']

# 設定畫布與子圖
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(14, 10), sharex=True)

# --- 經濟艙 ---
sns.boxplot(x='出發日期', y='最低價格_log', data=economy_data, ax=axes[0], color='skyblue')
axes[0].axhline(economy_data['最低價格_log'].mean(), color='blue', linestyle='--', linewidth=1.5)
axes[0].set_title('經濟艙 - 最低價格（log）分布', fontsize=14, weight='bold')
axes[0].set_ylabel('最低價格（log）', fontsize=12)
axes[0].tick_params(axis='x', rotation=45)

# --- 商務艙 ---
sns.boxplot(x='出發日期', y='最低價格_log', data=business_data, ax=axes[1], color='navajowhite')
axes[1].axhline(business_data['最低價格_log'].mean(), color='darkorange', linestyle='--', linewidth=1.5)
axes[1].set_title('商務艙 - 最低價格（log）分布', fontsize=14, weight='bold')
axes[1].set_xlabel('出發日期', fontsize=12)
axes[1].set_ylabel('最低價格（log）', fontsize=12)
axes[1].tick_params(axis='x', rotation=45)

# 整體美化
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 相關係數圖

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 設定字體與風格（繁體中文顯示 + 簡潔日系風）
plt.rcParams['font.family'] = 'Arial Unicode MS'
plt.rcParams['axes.unicode_minus'] = False

# 讀取資料
file_path = '/Users/yuchingchen/Documents/專題/merge_and_cleaned/final_data/long_flight.csv'
data = pd.read_csv(file_path)

# 數值型變數
numerical_cols = [
    '停留時間_分鐘', '實際飛行時間_分鐘', '經濟指標', '機場指標', 'competing_flights'
]

# 計算皮爾森相關係數
corr_matrix = data[numerical_cols].corr(method='pearson')

# 畫圖
plt.figure(figsize=(9, 7))
sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".2f",
    cmap=sns.color_palette("blend:#e0f3f8,#4575b4", as_cmap=True),
    annot_kws={"size": 13, "weight": "bold", "color": "black"},
    linewidths=0.4,
    linecolor='white',
    cbar_kws={"shrink": 0.8}
)

# 美化標題與刻度
plt.title("皮爾森相關係數熱力圖", fontsize=16, weight='bold', pad=15)
plt.xticks(rotation=0, fontsize=12)
plt.yticks(rotation=0, fontsize=12)
plt.tight_layout()
plt.show()
